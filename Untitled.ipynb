# %%
import pandas as pd
df= pd.read_csv("cleaned_data.csv", encoding='latin-1', engine = 'python')

# %%
df
# Out:
#             Date                                           Location  \
# 0     17/09/1908                                Fort Myer, Virginia
# 1     12/07/1912                          Atlantic City, New Jersey
# 2     06/08/1913                 Victoria, British Columbia, Canada
# 3     09/09/1913                                          North Sea
# 4     17/10/1913                              Johannisthal, Germany
# 5     05/03/1915                                    Tienen, Belgium
# 6     03/09/1915                                  Cuxhaven, Germany
# 7     28/07/1916                                   Jambol, Bulgeria
# 8     24/09/1916                                Billericay, England
# 9     01/10/1916                               Potters Bar, England
# 10    21/11/1916                                     Mainz, Germany
# 11    28/11/1916                           West Hartlepool, England
# 12    04/03/1917                                      Gent, Belgium
# ...

# %%
df_test = df.head(150)
df_test
# Out:
#            Date                            Location  \
# 0    17/09/1908                 Fort Myer, Virginia
# 1    12/07/1912           Atlantic City, New Jersey
# 2    06/08/1913  Victoria, British Columbia, Canada
# 3    09/09/1913                           North Sea
# 4    17/10/1913               Johannisthal, Germany
# 5    05/03/1915                     Tienen, Belgium
# 6    03/09/1915                   Cuxhaven, Germany
# 7    28/07/1916                    Jambol, Bulgeria
# 8    24/09/1916                 Billericay, England
# 9    01/10/1916                Potters Bar, England
# 10   21/11/1916                      Mainz, Germany
# 11   28/11/1916            West Hartlepool, England
# 12   04/03/1917                       Gent, Belgium
# 13   30/03/1917                             Germany
# 14   14/05/1917             Texel Island, North Sea
# 15   14/06/1917          Vlieland Island, North Sea
# 16   21/08/1917                             Denmark
# ...

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here",timeout = None)
crash_lat = []
crash_long = []

i = 0
y = 149
for index,row in df.iterrows():
    try:
        location = geolocator.geocode(row['Location'][i:y])
        lat = location.latitude
        long = location.longitude
        crash_lat.append(lat)
        crash_long.append(long)
    except AttributeError:
        crash_lat.append("error")
        crash_long.append("error")
i =+ 150
y =+ 150
print(crash_lat)
print(crash_long)
# print((location.latitude, location.longitude))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here",timeout = None)
crash_lat = []
crash_long = []    
for index,row in df_test.iterrows():
    try:
        location = geolocator.geocode(row['Location'])
        lat = location.latitude
        long = location.longitude
        crash_lat.append(lat)
        crash_long.append(long)
    except AttributeError:
        crash_lat.append("error")
        crash_long.append("error")
        
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
# ...
